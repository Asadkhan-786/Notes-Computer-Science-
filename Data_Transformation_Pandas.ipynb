# %% [markdown]
# <a href="https://colab.research.google.com/github/Asadkhan-786/Notes-Computer-Science-/blob/Pandas/Data_Transformation_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
flights = pd.read_csv('/content/flights2DCMDVA (1).csv')

# %%
## let's take a look at the first 5 rows.
flights.head(3)
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     629.0       -1.0     721.0      -19.0      WN  N273WN
# 1  2013      1    1     848.0      853.0    1001.0      851.0      MQ  N942MQ
# 2  2013      1    1    1059.0       -1.0    1201.0      -14.0      WN  N505SW
#
#    flight origin dest  air_time  distance  hour  minute
# 0    4646    LGA  BWI      40.0       185   6.0    29.0
# 1    3944    JFK  BWI      41.0       184   8.0    48.0
# 2     321    LGA  BWI      43.0       185  10.0    59.0

# %%
flights.tail(2)
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 17164  2013     12   31    1447.0       -7.0    1604.0      -27.0      9E
# 17165  2013     12   31    2057.0      197.0    2215.0      195.0      B6
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# 17164  N8477R    2946    JFK  IAD      51.0       228  14.0    47.0
# 17165  N292JB    1407    JFK  IAD      53.0       228  20.0    57.0

# %%
## check info for the dataframe
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17166 entries, 0 to 17165
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       17166 non-null  int64
#  1   month      17166 non-null  int64
#  2   day        17166 non-null  int64
#  3   dep_time   16227 non-null  float64
#  4   dep_delay  16227 non-null  float64
#  5   arr_time   16180 non-null  float64
#  6   arr_delay  16164 non-null  float64
#  7   carrier    17166 non-null  object
#  8   tailnum    16791 non-null  object
#  9   flight     17166 non-null  int64
#  10  origin     17166 non-null  object
#  11  dest       17166 non-null  object
#  12  air_time   16164 non-null  float64
#  13  distance   17166 non-null  int64
#  14  hour       16227 non-null  float64
#  15  minute     16227 non-null  float64
# dtypes: float64(7), int64(5), object(4)
# memory usage: 2.1+ MB

# %%
flights.shape
# Out:
# (17166, 16)

# %%
flights.describe()
# Out:
#           year         month           day      dep_time     dep_delay  \
# count  17166.0  17166.000000  17166.000000  16227.000000  16227.000000
# mean    2013.0      6.244961     15.555983   1383.986874     13.155605
# std        0.0      3.442076      8.741055    491.095434     41.697742
# min     2013.0      1.000000      1.000000      2.000000    -32.000000
# 25%     2013.0      3.000000      8.000000    956.000000     -6.000000
# 50%     2013.0      6.000000     15.000000   1435.000000     -3.000000
# 75%     2013.0      9.000000     23.000000   1819.000000     11.000000
# max     2013.0     12.000000     31.000000   2400.000000    853.000000
#
#            arr_time     arr_delay        flight      air_time      distance  \
# count  16180.000000  16164.000000  17166.000000  16164.000000  17166.000000
# mean    1497.763412     10.839396   3666.891530     45.743752    212.319352
# std      501.357545     45.410635   1390.491929      6.551112     14.252636
# min        1.000000    -62.000000     63.000000     31.000000    169.000000
# 25%     1109.000000    -13.000000   2187.000000     41.000000    212.000000
# 50%     1543.000000     -3.000000   3761.000000     45.000000    214.000000
# 75%     1922.000000     16.000000   4418.000000     49.000000    228.000000
# max     2400.000000    851.000000   6181.000000    131.000000    229.000000
#
#                hour        minute
# count  16227.000000  16227.000000
# mean      13.489554     35.031429
# std        4.943119     19.029893
# min        0.000000      0.000000
# 25%        9.000000     19.000000
# 50%       14.000000     38.000000
# 75%       18.000000     53.000000
# max       24.000000     59.000000

# %%
## pick all the flights with 'UA' as the carrier
flights[flights.carrier == 'UA']
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 12879  2013      9    8     820.0      -10.0     920.0      -24.0      UA
# 16391  2013     12   12     628.0       -7.0     743.0      -12.0      UA
# 16460  2013     12   15     915.0       13.0    1029.0       13.0      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# 12879  N37255    1037    EWR  IAD      44.0       212   8.0    20.0
# 16391  N834UA     625    EWR  DCA      45.0       199   6.0    28.0
# 16460  N817UA     625    EWR  DCA      42.0       199   9.0    15.0

# %%
flights[flights.carrier == 'UA'].drop('carrier', axis=1)
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay tailnum  \
# 12879  2013      9    8     820.0      -10.0     920.0      -24.0  N37255
# 16391  2013     12   12     628.0       -7.0     743.0      -12.0  N834UA
# 16460  2013     12   15     915.0       13.0    1029.0       13.0  N817UA
#
#        flight origin dest  air_time  distance  hour  minute
# 12879    1037    EWR  IAD      44.0       212   8.0    20.0
# 16391     625    EWR  DCA      45.0       199   6.0    28.0
# 16460     625    EWR  DCA      42.0       199   9.0    15.0

# %%
## check what happens if we just execute the inside code in previous code
trues_falses = (flights.carrier == 'UA').values

# %%
## let's talk about Boolean Masking
flights[trues_falses]
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 12879  2013      9    8     820.0      -10.0     920.0      -24.0      UA
# 16391  2013     12   12     628.0       -7.0     743.0      -12.0      UA
# 16460  2013     12   15     915.0       13.0    1029.0       13.0      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# 12879  N37255    1037    EWR  IAD      44.0       212   8.0    20.0
# 16391  N834UA     625    EWR  DCA      45.0       199   6.0    28.0
# 16460  N817UA     625    EWR  DCA      42.0       199   9.0    15.0

# %%
## Let's combine multiple conditions
## in addition to carrier let's use dep_delay comparison

flights[(flights.carrier == 'UA') & (flights.dep_delay > 3)]
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 16460  2013     12   15     915.0       13.0    1029.0       13.0      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# 16460  N817UA     625    EWR  DCA      42.0       199   9.0    15.0

# %% [markdown]
# ## Missing Values

# %% [markdown]
# [Missing Values in Pandas](https://jakevdp.github.io/PythonDataScienceHandbook/03.04-missing-values.html)

# %%
## let's use .isnull to see how pandas is handling missing values
## also use notnull for a column to find all the observations with valid values 
## in that column

# %%
flights.notnull()
# Out:
#        year  month   day  dep_time  dep_delay  arr_time  arr_delay  carrier  \
# 0      True   True  True      True       True      True       True     True
# 1      True   True  True      True       True      True       True     True
# 2      True   True  True      True       True      True       True     True
# 3      True   True  True      True       True      True       True     True
# 4      True   True  True      True       True      True       True     True
# ...     ...    ...   ...       ...        ...       ...        ...      ...
# 17161  True   True  True      True       True      True       True     True
# 17162  True   True  True      True       True      True       True     True
# 17163  True   True  True      True       True      True       True     True
# 17164  True   True  True      True       True      True       True     True
# 17165  True   True  True      True       True      True       True     True
#
#        tailnum  flight  origin  dest  air_time  distance  hour  minute
# 0         True    True    True  True      True      True  True    True
# 1         True    True    True  True      True      True  True    True
# 2         True    True    True  True      True      True  True    True
# 3         True    True    True  True      True      True  True    True
# 4         True    True    True  True      True      True  True    True
# ...        ...     ...     ...   ...       ...       ...   ...     ...
# 17161     True    True    True  True      True      True  True    True
# 17162     True    True    True  True      True      True  True    True
# 17163     True    True    True  True      True      True  True    True
# 17164     True    True    True  True      True      True  True    True
# 17165     True    True    True  True      True      True  True    True
#
# [17166 rows x 16 columns]

# %% [markdown]
# [Operating on null values](https://jakevdp.github.io/PythonDataScienceHandbook/03.04-missing-values.html#Operating-on-Null-Values)

# %% [markdown]
# ## index of a dataframe

# %% [markdown]
# [Pandas - Documentation - Indexing and selecting Data](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html)

# %% [markdown]
# __Why indexing data?__
#
# - identifying observations
# - Allows intuitive subseting

# %% [markdown]
# __.loc__
# - Label based
# - will raise error if the item is not found.
#
# __.iloc__
#
# - Integer position based
# - will raise an error if the indexer is out-of-bounds. (slicer allow this)

# %% [markdown]
# __Examples__

# %%
## we can also use loc and iloc to subset columns
flights.loc[np.arange(6), ['carrier', 'dep_delay']]
# Out:
#   carrier  dep_delay
# 0      WN       -1.0
# 1      MQ      853.0
# 2      WN       -1.0
# 3      WN       -2.0
# 4      EV        2.0
# 5      9E        0.0

# %%
## iloc version
flights.iloc[np.arange(6), [9, 5]]
# Out:
#    flight  arr_time
# 0    4646     721.0
# 1    3944    1001.0
# 2     321    1201.0
# 3    1568    1256.0
# 4    4340    1412.0
# 5    3369    1650.0

# %%
## note that iloc would give an error
#flights.iloc[:, ['carrier', 'dep_delay']]

# %% [markdown]
# ## Sorting Values

# %%
## let's sort dep_delay column
# flights.dep_delay.sort_values(ascending = False)
flights['dep_delay'].sort_values(ascending = False)
# flights['dep_delay'].sort_values()
# Out:
# 1        853.0
# 10372    536.0
# 17002    503.0
# 2722     404.0
# 17001    392.0
#          ...
# 17115      NaN
# 17116      NaN
# 17147      NaN
# 17157      NaN
# 17158      NaN
# Name: dep_delay, Length: 17166, dtype: float64

# %%
## Use ascending parameter to reverse the ordering 
flights.dep_delay.sort_values()
# Out:
# 15695   -32.0
# 7436    -23.0
# 15913   -20.0
# 11697   -20.0
# 7327    -19.0
#          ...
# 17115     NaN
# 17116     NaN
# 17147     NaN
# 17157     NaN
# 17158     NaN
# Name: dep_delay, Length: 17166, dtype: float64

# %%
## We can also sort 'string' values
flights.carrier.sort_values()
# Out:
# 11934    9E
# 11932    9E
# 11930    9E
# 11929    9E
# 3470     9E
#          ..
# 8687     YV
# 14346    YV
# 8673     YV
# 7188     YV
# 5796     YV
# Name: carrier, Length: 17166, dtype: object

# %% [markdown]
# ## Counting Values

# %%
## How many times a carrier make flights.
flights.carrier.value_counts()
# Out:
# EV    6110
# US    4710
# 9E    2592
# MQ    2554
# B6     675
# YV     311
# WN     208
# UA       3
# DL       2
# OO       1
# Name: carrier, dtype: int64

# %%
## We can use "dropna" to count missing values
flights.dep_delay.value_counts(dropna = True)
# Out:
# -5.0      1372
# -6.0      1305
# -7.0      1239
# -4.0      1137
# -3.0      1001
#           ...
# -23.0        1
#  201.0       1
#  215.0       1
#  208.0       1
#  296.0       1
# Name: dep_delay, Length: 305, dtype: int64

# %%
flights.dep_delay.value_counts(dropna = True, bins = 15)
# Out:
# (-32.885999999999996, 27.0]    13420
# (27.0, 86.0]                    1840
# (86.0, 145.0]                    603
# (145.0, 204.0]                   231
# (204.0, 263.0]                    82
# (263.0, 322.0]                    33
# (322.0, 381.0]                    11
# (381.0, 440.0]                     4
# (499.0, 558.0]                     2
# (794.0, 853.0]                     1
# (440.0, 499.0]                     0
# (558.0, 617.0]                     0
# (617.0, 676.0]                     0
# (676.0, 735.0]                     0
# (735.0, 794.0]                     0
# Name: dep_delay, dtype: int64

# %%
edges = [-100, 0, 30, 60, 120, 240, 720]
flights.dep_delay.value_counts(dropna = True, bins = edges)
# Out:
# (-100.001, 0.0]    10447
# (0.0, 30.0]         3143
# (30.0, 60.0]        1074
# (60.0, 120.0]       1032
# (120.0, 240.0]       457
# (240.0, 720.0]        73
# Name: dep_delay, dtype: int64

# %%
## we can directly use nunique and unique to count unique values in a column
flights.carrier.nunique()
# Out:
# 10

# %%
flights.carrier.unique()
# Out:
# array(['WN', 'MQ', 'EV', '9E', 'US', 'DL', 'B6', 'YV', 'UA', 'OO'],
#       dtype=object)

# %% [markdown]
# ## Summary Information: Revisited

# %%
## let's see the basic summary statistics for ['dep_delay', 'arr_time', 'arr_delay']
flights[['dep_delay', 'arr_time', 'arr_delay']].describe()
# Out:
#           dep_delay      arr_time     arr_delay
# count  16227.000000  16180.000000  16164.000000
# mean      13.155605   1497.763412     10.839396
# std       41.697742    501.357545     45.410635
# min      -32.000000      1.000000    -62.000000
# 25%       -6.000000   1109.000000    -13.000000
# 50%       -3.000000   1543.000000     -3.000000
# 75%       11.000000   1922.000000     16.000000
# max      853.000000   2400.000000    851.000000

# %%
## Let's visualize this
arr_delay = flights.arr_delay.dropna().values
plt.figure(figsize = (15, 5))
plt.boxplot(arr_delay, vert = False)
plt.show()

# %%
arr_delay = flights.arr_delay.dropna().values
arr_delay
# Out:
# array([-19., 851., -14., ...,  -9., -27., 195.])

# %%
plt.figure(figsize = (15, 5))
plt.hist(arr_delay,bins=[0, 5, 10, 20, 30, 50, 75, 100, 120, 150, 200])
plt.show()

# %%
# let's plot sorted values of arr_delay between x = 0 (where min arr_delay occurs) and x = 100 (where max arr_delay happens)
x = np.arange(len(arr_delay)) / len(arr_delay)*100
plt.figure(figsize = (15, 5))
plt.plot(x,np.sort(arr_delay))
plt.show()

# %%
## we can also use .quantile method to find a value of the quantile
flights.arr_delay.quantile(0.99)
# Out:
# 196.0

# %%
flights.arr_delay.quantile(0.80)
# Out:
# 25.0

# %%
## We can use other summary statistics
## max
flights.arr_delay.max()
# Out:
# 851.0

# %%
## min
flights.arr_delay.min()
# Out:
# -62.0

# %%
## std

flights.arr_delay.std()
# Out:
# 45.41063515951926

# %%
## variance
flights.arr_delay.var()
# Out:
# 2062.1257855909666

# %% [markdown]
# ## Group_By method: Basics

# %%
monthly_mean_dep_delays = flights.groupby(['month']).dep_delay.mean()
monthly_mean_dep_delays
# Out:
# month
# 1     14.010031
# 2     13.193593
# 3     12.571429
# 4     13.464451
# 5     15.084972
# 6     19.015323
# 7     22.407213
# 8     12.836524
# 9      5.382072
# 10     7.283977
# 11     5.958365
# 12    18.192529
# Name: dep_delay, dtype: float64

# %%
plt.figure(figsize = (15, 5))
plt.plot(monthly_mean_dep_delays)
plt.show()

# %%
## Let's group the flights data with day column
## and take a look at total delays happened for each day
daily_total_dep_delays = flights.groupby(['day']).dep_delay.sum()
daily_total_dep_delays
# Out:
# day
# 1      8993.0
# 2      7976.0
# 3      7351.0
# 4      3807.0
# 5      3185.0
# 6      4166.0
# 7      7133.0
# 8     11341.0
# 9      8313.0
# 10     7952.0
# 11     8116.0
# 12     7356.0
# 13     7021.0
# 14     3645.0
# 15     3205.0
# 16     4742.0
# 17     9635.0
# 18     6915.0
# 19    10509.0
# 20     4484.0
# 21     5524.0
# 22    10127.0
# 23    10846.0
# 24    10767.0
# 25     8955.0
# 26     5555.0
# 27     7115.0
# 28     8490.0
# 29     2901.0
# 30     3549.0
# 31     3802.0
# Name: dep_delay, dtype: float64

# %%
plt.figure(figsize = (15, 5))
plt.plot(daily_total_dep_delays)
plt.show()

# %% [markdown]
# __Under the hood__ <br>

# %%
## Group Flights by destination and
## take a look at the average delay for each day of the month
delays_destination = flights.groupby('dest').dep_delay.mean()
delays_destination
# Out:
# dest
# BWI    16.410029
# DCA    10.298863
# IAD    16.984955
# Name: dep_delay, dtype: float64

# %%
## Let's visualize this
# change the style if you wish
plt.style.use('seaborn-talk')

# figure size
plt.figure(figsize = (20, 7))

# Histogram
plt.bar(delays_destination.index, delays_destination.values)

# x-label
plt.xlabel('Destination Airport')

# y-label
plt.ylabel('Average Delays')

# x_ticks
plt.xticks(rotation = 90)

# Show
plt.show()

# %%
## let's take a look at the destinations with 
## avg delay is more than 25
delays_destination[delays_destination >25]
# Out:
# Series([], Name: dep_delay, dtype: float64)

# %% [markdown]
# ## Aggregation

# %%
## First create a agg_dictionary
agg_dictionary = {'dest': 'count', 'dep_delay': 'mean'}

## use the dictionary we created above in .aggregate method
flights.groupby('dest').aggregate(agg_dictionary)
# Out:
#       dest  dep_delay
# dest
# BWI   1780  16.410029
# DCA   9695  10.298863
# IAD   5691  16.984955

# %% [markdown]
# __Let's check our hypothesis:__

# %%
## store the resulting dataframe above in a variable aggregated_df
aggregated_df = flights.groupby('dest').aggregate(agg_dictionary)

## check the values with destinations with more than 25mins average delay
print(aggregated_df[aggregated_df.dep_delay >25])
# Out:
# Empty DataFrame
# Columns: [dest, dep_delay]
# Index: []

# %%
## Note that the count is 631 for the TYS 
## see how many other destinations have less than this value
## as their flights count.
aggregated_df[aggregated_df.dest >631].shape
# Out:
# (3, 2)

# %% [markdown]
# ### Aggregation and naming columns of the resulting table

# %% [markdown]
# Proper way of aggregation

# %%
grouped_by_dest = flights.groupby('dest').agg(
    flight_counts = ('dest', 'count') , 
    delay_mean= ('dep_delay', 'mean') ,
    distance_mean = ('distance', 'mean')
    )
grouped_by_dest
# Out:
#       flight_counts  delay_mean  distance_mean
# dest
# BWI            1780   16.410029     179.415730
# DCA            9695   10.298863     211.003507
# IAD            5691   16.984955     224.852399

# %% [markdown]
# ### User defined functions

# %% [markdown]
# Finally we can use user-defined functions for aggregation

# %%
# define my_avg_funct
def my_avg_funct(x):
  return x.mean()

# %%
# let's use my_avg_func instead of 'mean'
grouped_by_dest = flights.groupby('dest').agg(
    flight_counts = ('dest', 'count') , 
    delay_mean= ('dep_delay', 'mean') ,
    distance_mean = ('arr_delay', my_avg_funct)
    )
grouped_by_dest
# Out:
#       flight_counts  delay_mean  distance_mean
# dest
# BWI            1780   16.410029      10.745552
# DCA            9695   10.298863       9.069106
# IAD            5691   16.984955      13.866071

# %%
## we can also use built-in functions from other libraries
## especially from numpy

# %% [markdown]
# ## Grouping by multiple variables

# %%
multiple_grouped = flights.groupby(['origin', 'dest']).dep_delay.mean()

multiple_grouped
# Out:
# origin  dest
# EWR     BWI     18.502857
#         DCA     21.256491
#         IAD     18.568220
# JFK     BWI     15.630303
#         DCA     12.437824
#         IAD     16.422117
# LGA     BWI      3.200000
#         DCA      4.963624
#         IAD     16.693791
# Name: dep_delay, dtype: float64

# %% [markdown]
# Now we can access a group by usign its multiple index:

# %% [markdown]
# ## Filtering
#
# A filtering operation allows you to drop data based on the group properties.

# %% [markdown]
# Note that this is not equal to getting all flights whose delay time is more than 25 mins.

# %%
# return all the flights with more than 25 mins delay
flights[flights.dep_delay > 25]
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 1      2013      1    1     848.0      853.0    1001.0      851.0      MQ
# 11     2013      1    2    1003.0      103.0    1105.0       85.0      9E
# 14     2013      1    2    1421.0       67.0    1515.0       60.0      EV
# 17     2013      1    2    1829.0       67.0    1940.0       77.0      EV
# 20     2013      1    2    2150.0      105.0    2255.0       89.0      9E
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 17144  2013     12   29    1851.0       71.0    2007.0       67.0      B6
# 17145  2013     12   29    1914.0      129.0    2026.0      124.0      EV
# 17146  2013     12   29    2111.0       96.0    2229.0       94.0      EV
# 17161  2013     12   31    1105.0       53.0    1211.0       36.0      EV
# 17165  2013     12   31    2057.0      197.0    2215.0      195.0      B6
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# 1      N942MQ    3944    JFK  BWI      41.0       184   8.0    48.0
# 11     N8968E    3694    JFK  BWI      39.0       184  10.0     3.0
# 14     N16559    4340    EWR  BWI      37.0       169  14.0    21.0
# 17     N15986    4151    EWR  BWI      35.0       169  18.0    29.0
# 20     N8976E    4091    JFK  BWI      39.0       184  21.0    50.0
# ...       ...     ...    ...  ...       ...       ...   ...     ...
# 17144  N179JB    1407    JFK  IAD      49.0       228  18.0    51.0
# 17145  N13956    6049    EWR  IAD      45.0       212  19.0    14.0
# 17146  N832AS    5714    JFK  IAD      51.0       228  21.0    11.0
# 17161  N835AS    5769    LGA  IAD      44.0       229  11.0     5.0
# 17165  N292JB    1407    JFK  IAD      53.0       228  20.0    57.0
#
# [2915 rows x 16 columns]

# %%
## when we use groupby method pandas returns a groupby object
grouped = flights.groupby('dest')

# %% [markdown]
# ## Transform Method

# %% [markdown]
# Pandas.Series objects supports vectorized operations.

# %%
flights['speed_per_hour'] = flights.distance/flights.air_time*60

# %%
flights.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     629.0       -1.0     721.0      -19.0      WN  N273WN
# 1  2013      1    1     848.0      853.0    1001.0      851.0      MQ  N942MQ
# 2  2013      1    1    1059.0       -1.0    1201.0      -14.0      WN  N505SW
# 3  2013      1    1    1158.0       -2.0    1256.0       -4.0      WN  N783SW
# 4  2013      1    1    1316.0        2.0    1412.0       -3.0      EV  N11551
#
#    flight origin dest  air_time  distance  hour  minute  speed_per_hour
# 0    4646    LGA  BWI      40.0       185   6.0    29.0      277.500000
# 1    3944    JFK  BWI      41.0       184   8.0    48.0      269.268293
# 2     321    LGA  BWI      43.0       185  10.0    59.0      258.139535
# 3    1568    EWR  BWI      38.0       169  11.0    58.0      266.842105
# 4    4340    EWR  BWI      38.0       169  13.0    16.0      266.842105

# %% [markdown]
# Now let's compare each observation with the mean of their destination group.

# %%
def speed_func(group):
  return group - group.mean()

# %%
flights['speed_dif_from_group'] = flights.groupby('dest')['speed_per_hour'].transform(speed_func)
flights.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     629.0       -1.0     721.0      -19.0      WN  N273WN
# 1  2013      1    1     848.0      853.0    1001.0      851.0      MQ  N942MQ
# 2  2013      1    1    1059.0       -1.0    1201.0      -14.0      WN  N505SW
# 3  2013      1    1    1158.0       -2.0    1256.0       -4.0      WN  N783SW
# 4  2013      1    1    1316.0        2.0    1412.0       -3.0      EV  N11551
#
#    flight origin dest  air_time  distance  hour  minute  speed_per_hour  \
# 0    4646    LGA  BWI      40.0       185   6.0    29.0      277.500000
# 1    3944    JFK  BWI      41.0       184   8.0    48.0      269.268293
# 2     321    LGA  BWI      43.0       185  10.0    59.0      258.139535
# 3    1568    EWR  BWI      38.0       169  11.0    58.0      266.842105
# 4    4340    EWR  BWI      38.0       169  13.0    16.0      266.842105
#
#    speed_dif_from_group
# 0             -4.899410
# 1            -13.131117
# 2            -24.259875
# 3            -15.557305
# 4            -15.557305

# %% [markdown]
# __Transforming Missing Values with Group Mean__

# %%
def my_filling_func(group):
  m = group.mean()
  if np.isnan(m):
    return -9999
  else:
    return group.fillna(m)

# %%
flights['air_time'] = flights.groupby('dest')['air_time'].transform(my_filling_func)
flights.tail(3)
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 17163  2013     12   31    1430.0       -2.0    1546.0       -9.0      YV
# 17164  2013     12   31    1447.0       -7.0    1604.0      -27.0      9E
# 17165  2013     12   31    2057.0      197.0    2215.0      195.0      B6
#
#       tailnum  flight origin dest  air_time  distance  hour  minute  \
# 17163  N515MJ    3771    LGA  IAD      52.0       229  14.0    30.0
# 17164  N8477R    2946    JFK  IAD      51.0       228  14.0    47.0
# 17165  N292JB    1407    JFK  IAD      53.0       228  20.0    57.0
#
#        speed_per_hour  speed_dif_from_group
# 17163      264.230769            -20.884849
# 17164      268.235294            -16.880324
# 17165      258.113208            -27.002411

# %% [markdown]
# another transform example

# %%
def relative_contribution_to_total_delay(group):
  return group/group.sum()

# %%
flights['dep_delay_relative_transform'] = flights.groupby(['origin', 'dest', 'month', 'day'])['dep_delay'].transform(relative_contribution_to_total_delay) 
flights.head(13)
# Out:
#     year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0   2013      1    1     629.0       -1.0     721.0      -19.0      WN
# 1   2013      1    1     848.0      853.0    1001.0      851.0      MQ
# 2   2013      1    1    1059.0       -1.0    1201.0      -14.0      WN
# 3   2013      1    1    1158.0       -2.0    1256.0       -4.0      WN
# 4   2013      1    1    1316.0        2.0    1412.0       -3.0      EV
# 5   2013      1    1    1530.0        0.0    1650.0       -5.0      9E
# 6   2013      1    1    1815.0       10.0    1928.0        8.0      WN
# 7   2013      1    1    1957.0       -8.0    2100.0      -26.0      9E
# 8   2013      1    1    2158.0       -2.0    2254.0      -13.0      EV
# 9   2013      1    2     628.0       13.0     730.0       15.0      WN
# 10  2013      1    2     630.0        0.0     727.0      -13.0      WN
# 11  2013      1    2    1003.0      103.0    1105.0       85.0      9E
# 12  2013      1    2    1101.0        1.0    1201.0      -14.0      WN
#
#    tailnum  flight origin dest  air_time  distance  hour  minute  \
# 0   N273WN    4646    LGA  BWI      40.0       185   6.0    29.0
# 1   N942MQ    3944    JFK  BWI      41.0       184   8.0    48.0
# 2   N505SW     321    LGA  BWI      43.0       185  10.0    59.0
# 3   N783SW    1568    EWR  BWI      38.0       169  11.0    58.0
# 4   N11551    4340    EWR  BWI      38.0       169  13.0    16.0
# 5   N913XJ    3369    JFK  BWI      40.0       184  15.0    30.0
# 6   N266WN     731    LGA  BWI      46.0       185  18.0    15.0
# 7   N8598B    4091    JFK  BWI      41.0       184  19.0    57.0
# 8   N14998    4103    EWR  BWI      36.0       169  21.0    58.0
# 9   N961WN    3641    EWR  BWI      42.0       169   6.0    28.0
# 10  N7735A    4648    LGA  BWI      42.0       185   6.0    30.0
# 11  N8968E    3694    JFK  BWI      39.0       184  10.0     3.0
# 12  N701GS    3094    LGA  BWI      35.0       185  11.0     1.0
#
#     speed_per_hour  speed_dif_from_group  dep_delay_relative_transform
# 0       277.500000             -4.899410                     -0.125000
# 1       269.268293            -13.131117                      1.009467
# 2       258.139535            -24.259875                     -0.125000
# 3       266.842105            -15.557305                      1.000000
# 4       266.842105            -15.557305                     -1.000000
# 5       276.000000             -6.399410                      0.000000
# 6       241.304348            -41.095062                      1.250000
# 7       269.268293            -13.131117                     -0.009467
# 8       281.666667             -0.732743                      1.000000
# 9       241.428571            -40.970839                      0.053061
# 10      264.285714            -18.113696                     -0.000000
# 11      283.076923              0.677513                      0.517588
# 12      317.142857             34.743447                     -0.250000
